# %%
import numpy as np
import pandas as pd
import xgboost
import shap
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
import warnings
from copy import deepcopy
import matplotlib.pyplot as plt
from xgboost import plot_importance
import seaborn as sns
sns.set_style("darkgrid")
sns.set_context("poster")
sns.set_palette("cubehelix", 8)#"deep")
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from problem_creator import gen_regression_symbolic, gen_classification_symbolic
from scipy.stats import weightedtau
from mlxtend.evaluate import feature_importance_permutation

# %%
x = [1,2,3,4,5,6]
y = [10,9,7,6,4,3]
txt = ['Neural Networks \n(CNNs, GANS)','Ensemble Methods \n(XGBoost)','Kernel Based Methods \n(Support Vector Machines)','Decision Trees','Logistic Regression']

# %%
fz = 20

plt.figure(figsize=(10,7))
plt.plot(x,y, marker='o',linestyle='--',color='C3',mec='C1',mfc='C1',markersize=8)
plt.xticks([1,2,3,4,5,6,7],['','','','','','',''])
plt.yticks([11,10,9,8,7,6,5,4],['','','','','','','',''])
#plt.xlabel('Low                                   Interpretability                                  High',fontsize=fz)
#plt.ylabel('Low                       Accuracy                      High',fontsize=fz)
plt.ylabel('Accuracy >',fontsize=fz)
plt.xlabel('Interpretability >',fontsize=fz)
#plt.grid(True)

for i, t in enumerate(txt):
    plt.annotate(t, (x[i]+0.3,y[i]),fontsize=fz-5,color='C1')

plt.title('Trade-Off \n Model Accuracy vs. Model Interpretability',fontsize=fz+2)
#plt.colorbar(x,ticks=None)
#plt.arrow(0,0,5,5)
plt.grid(True)
plt.show()
